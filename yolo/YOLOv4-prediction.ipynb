# %% [markdown]
# ##### This notebook was created using this training tutorial:
# ###### https://colab.research.google.com/drive/1_GdoqCJWXsChrOiY8sZMr_zbr_fH-0Fg?usp=sharing

# %% [markdown]
# ### Cloning and Building Darknet

# %%
# !git clone https://github.com/AlexeyAB/darknet
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version

# %%
# make darknet
# !make

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18,10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
# training
# !./darknet detector train data/obj.data cfg/yolov4-obj.cfg yolov4.conv.137 -dont_show -map

# %% [markdown]
# Run detection on test image

# %%
# !./darknet detector test data/obj.data cfg/yolov4-obj.cfg yolov4-obj_final.weights data/obj/10sfg465970_crop10.png
imShow('predictions.jpg')
